# %%
a = 10
b = a
a = 20
print(b)
# Out:
# 10

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was immutable.
# 2. Did python mutate the object or rebind the name?
#    - it rebinded it.
# 3. Did the change affect other references?
#    - It didn't affect other references.

# %%
def f(x):
   x = x + 1
   print(x)

n = 5
f(5)
print(n)
# Out:
# 6
# 5

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was immutable.
# 2. Did python mutate the object or rebind the name?
#    - it rebinded it.
# 3. Did the change affect other references?
#    - It didn't affect other references.

# %%
x = 5
print(id(x))
x += 1
print (id(x))
# Out:
# 11654504
# 11654536

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was immutable.
# 2. Did python mutate the object or rebind the name?
#    - it rebinded it.
# 3. Did the change affect other references?
#    - It didn't affect other references.

# %%
lst = [1, 2]
print(id(lst))
lst.append(3)
print(id(lst))
# Out:
# 133068687967680
# 133068687967680

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was mutable.
# 2. Did python mutate the object or rebind the name?
#    - it mutated it.
# 3. Did the change affect other references?
#    - It affected other references.

# %%
def change(x):
   x = x + 10

a = 5
change(a)
print(a)
# Out:
# 5

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was immutable.
# 2. Did python mutate the object or rebind the name?
#    - it rebinded it.
# 3. Did the change affect other references?
#    - It didn't affect other references.

# %%
def change(lst):
   lst.append(99)

data = [1, 2]
change(data)
print(data)
# Out:
# [1, 2, 99]

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was mutable.
# 2. Did python mutate the object or rebind the name?
#    - it mutated it.
# 3. Did the change affect other references?
#    - It affected other references.

# %%
def reset_wrong(lst):
   lst = []

def reset_right(lst):
   lst.clear()

data = [1, 2, 3]
reset_wrong(data)
print(data)

reset_right(data)
print(data)
# Out:
# [1, 2, 3]
# []

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was mutable.
# 2. Did python mutate the object or rebind the name?
#    - it mutated it.
# 3. Did the change affect other references?
#    - It affected other references.

# %%
def demon(x):
  print(id(x))
  x.append(5)
  print(id(x))

lst = [1, 2]
print(id(lst))
demon(lst)
# Out:
# 135034030248256
# 135034030248256
# 135034030248256

# %% [markdown]
# 1. was the object mutable or immutable?
#    - it was mutable.
# 2. Did python mutate the object or rebind the name?
#    - it mutated it.
# 3. Did the change affect other references?
#    - It affected other references.
